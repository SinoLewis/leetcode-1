# %% [markdown]
# Definition for a binary tree node.<br>
# class TreeNode(object):<br>
#     def __init__(self, x):<br>
#         self.val = x<br>
#         self.left = None<br>
#         self.right = None
